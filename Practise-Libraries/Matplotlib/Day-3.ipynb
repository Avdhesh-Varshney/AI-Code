# %% [markdown]
# # Day 3 - Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Coding Styles

# %% [markdown]
# #### There are 2 main coding styles in Matplotlib.
# 1. Explicitly (Object-oriented (OO) style)
# 2. Implicitly (pyplot functions for plotting)

# %% [markdown]
# #### Object Oriented Styles

# %%
x = np.linspace(0, 2, 100)
fig, ax = plt.subplots(figsize=(5, 2.8), constrained_layout=True)

ax.plot(x, x, label='linear')
ax.plot(x, x**2, label='quadratic')
ax.plot(x, x**3, label='cubic')

ax.set_xlabel('x')
ax.set_ylabel('y')

ax.set_title('Functions')
ax.legend()

# %% [markdown]
# #### Pyplot Style

# %%
x = np.linspace(0, 2, 100)
plt.figure(figsize=(5, 2.8), constrained_layout=True)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x')
plt.ylabel('y')

plt.title('Functions')
plt.legend()

plt.show()

# %% [markdown]
# ## Congratulate, Day 3 Finished!
