# %% [markdown]
# # Day 7 - Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Dates and Strings

# %% [markdown]
# ### Dates Example
#
# ```
# s - second
# m - minute
# h - hour
# d - day
# m - month
# y - year
# ```

# %%
np.random.seed(528)
fig, ax = plt.subplots(figsize=(5.8, 3), constrained_layout=True)
dates = np.arange(np.datetime64('2022-08-15'),
                  np.datetime64('2023-08-15'),
                 np.timedelta64(1, 'h'))
data = np.cumsum(np.random.randn(len(dates)))

ax.plot(dates, data)

cdf = mpl.dates.ConciseDateFormatter(ax.xaxis.get_major_locator())
ax.xaxis.set_major_formatter(cdf)

# %% [markdown]
# ## Categorical Plotting

# %%
np.random.seed(15)

fig, ax = plt.subplots(figsize=(5.8, 3), constrained_layout=True)

categories = ['onions', 'broccolis', 'cucumbers', 'pumpkins']

ax.bar(categories, np.random.rand(len(categories)))
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### More ways to represent the categorical variables.

# %%
data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}

names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(9, 3), constrained_layout=True, sharey=True)

axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)

# %% [markdown]
# #### Example 2

# %%
cat = ['bored', 'happy', 'bored', 'bored', 'happy', 'bored']
dog = ['happy', 'happy', 'happy', 'happy', 'bored', 'bored']

activity = ['combing', 'drinking', 'feeding', 'napping', 'playing', 'washing']

fig, ax = plt.subplots()

ax.plot(activity, dog, label='dog')
ax.plot(activity, cat, label='cat')

ax.legend()

plt.show()

# %% [markdown]
# ## Congratulate, Day 7 Finished!
